# %%
# !python --version
# Out:
# Python 3.10.7

# %%
#Preprocessing code borrowed from Fabrizio Ravelli: https://www.kaggle.com/code/fabrizioravelli/alzheimer-s-disease-classification-98-acc

import os
import cv2
import random
from tqdm import tqdm
import pickle

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras.backend as K

from keras import models
from keras import layers
from keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import Model



CLASSES = ("MILD_DEMENTED", "NON_DEMENTED", "VERYMILD_DEMENTED")
DATASET_DIR = "data/"
TEST_DIR = DATASET_DIR + "test/"
TRAINING_DIR = DATASET_DIR + "train/"

IMG_SIZE = 100

def create_data(directory):
    data = []
    for CLASSE in CLASSES:
        path = os.path.join(directory, CLASSE)
        class_num = CLASSES.index(CLASSE)
        for img in tqdm(os.listdir(path)):
            img_array = cv2.imread(os.path.join(path, img))
            img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
            data.append((img_array, class_num))
            
    return data

train_data = create_data(TRAINING_DIR)
test_data = create_data(TEST_DIR)

random.shuffle(train_data)
random.shuffle(test_data)

def prepare_data(data):
    inp = []
    out = []
    
    for img, label in data:
        inp.append(img)
        y = np.zeros(len(CLASSES))
        y[label] = 1
        out.append(y)
    inp = np.array(inp).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
    
    return inp, out

X_train, y_train = prepare_data(train_data)
X_test, y_test = prepare_data(test_data)

X_train = X_train / 255
y_train = np.array(y_train)

X_test = X_test / 255
y_test = np.array(y_test)

for classe in CLASSES:
    class_num = CLASSES.index(classe)
    print(classe, class_num)
# Out:
#   8%|██▉                                  | 64/802 [00:00<00:01, 621.82it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [2], in <cell line: 41>()
#      37             data.append((img_array, class_num))
#      39     return data
# ---> 41 train_data = create_data(TRAINING_DIR)
#      42 test_data = create_data(TEST_DIR)
#      44 random.shuffle(train_data)
#
# Input In [2], in create_data(directory)
#      34     for img in tqdm(os.listdir(path)):
#      35         img_array = cv2.imread(os.path.join(path, img))
# ---> 36         img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
#      37         data.append((img_array, class_num))
#      39 return data
#
# error: OpenCV(4.6.0) /io/opencv/modules/imgproc/src/resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
plt.imshow(X_train[6:7][0,:,:,:])
plt.xlabel("Mild Demented")

# %%
plt.imshow(X_train[37:38][0,:,:,:])
plt.xlabel("Very Mild Demented")

# %%
plt.imshow(X_train[65:66][0,:,:,:])
plt.xlabel("Non Demented")

# %%
X_train.shape[1:]

# %%
from keras.models import load_model

model =load_model('movelv11_100epochs')

model.summary()
# Out:
# 2022-08-23 09:51:31.627727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:31.689320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:31.691628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:31.694469: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-23 09:51:31.695884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:31.698023: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:31.700187: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:32.569268: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:32.570569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:32.571708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-23 09:51:32.572829: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6507 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Super with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "modelv3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 100, 100, 3  0           []
#                                 )]
#
#  conv2d_64 (Conv2D)             (None, 98, 98, 32)   896         ['input_8[0][0]']
#
#  average_pooling2d_62 (AverageP  (None, 49, 49, 32)  0           ['conv2d_64[0][0]']
#  ooling2D)
#
#  batch_normalization_62 (BatchN  (None, 49, 49, 32)  128         ['average_pooling2d_62[0][0]']
#  ormalization)
#
#  conv2d_65 (Conv2D)             (None, 47, 47, 64)   18496       ['batch_normalization_62[0][0]']
#
#  average_pooling2d_63 (AverageP  (None, 23, 23, 64)  0           ['conv2d_65[0][0]']
#  ooling2D)
#
#  batch_normalization_63 (BatchN  (None, 23, 23, 64)  256         ['average_pooling2d_63[0][0]']
#  ormalization)
#
#  conv2d_66 (Conv2D)             (None, 21, 21, 128)  73856       ['batch_normalization_63[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 96, 96, 128)  9728        ['input_8[0][0]']
#
#  average_pooling2d_64 (AverageP  (None, 10, 10, 128)  0          ['conv2d_66[0][0]']
#  ooling2D)
#
#  average_pooling2d_67 (AverageP  (None, 32, 32, 128)  0          ['conv2d_69[0][0]']
#  ooling2D)
#
#  batch_normalization_64 (BatchN  (None, 10, 10, 128)  512        ['average_pooling2d_64[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 32, 32, 128)  512        ['average_pooling2d_67[0][0]']
#  ormalization)
#
#  conv2d_67 (Conv2D)             (None, 8, 8, 256)    295168      ['batch_normalization_64[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 28, 28, 256)  819456      ['batch_normalization_67[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 94, 94, 128)  18944       ['input_8[0][0]']
#
#  average_pooling2d_65 (AverageP  (None, 4, 4, 256)   0           ['conv2d_67[0][0]']
#  ooling2D)
#
#  average_pooling2d_68 (AverageP  (None, 9, 9, 256)   0           ['conv2d_70[0][0]']
#  ooling2D)
#
#  average_pooling2d_70 (AverageP  (None, 18, 18, 128)  0          ['conv2d_72[0][0]']
#  ooling2D)
#
#  batch_normalization_65 (BatchN  (None, 4, 4, 256)   1024        ['average_pooling2d_65[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 9, 9, 256)   1024        ['average_pooling2d_68[0][0]']
#  ormalization)
#
#  batch_normalization_70 (BatchN  (None, 18, 18, 128)  512        ['average_pooling2d_70[0][0]']
#  ormalization)
#
#  conv2d_68 (Conv2D)             (None, 2, 2, 512)    1180160     ['batch_normalization_65[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 5, 5, 512)    3277312     ['batch_normalization_68[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 12, 12, 256)  1605888     ['batch_normalization_70[0][0]']
#
#  average_pooling2d_66 (AverageP  (None, 1, 1, 512)   0           ['conv2d_68[0][0]']
#  ooling2D)
#
#  average_pooling2d_69 (AverageP  (None, 1, 1, 512)   0           ['conv2d_71[0][0]']
#  ooling2D)
#
#  average_pooling2d_71 (AverageP  (None, 2, 2, 256)   0           ['conv2d_73[0][0]']
#  ooling2D)
#
#  batch_normalization_66 (BatchN  (None, 1, 1, 512)   2048        ['average_pooling2d_66[0][0]']
#  ormalization)
#
#  batch_normalization_69 (BatchN  (None, 1, 1, 512)   2048        ['average_pooling2d_69[0][0]']
#  ormalization)
#
#  batch_normalization_71 (BatchN  (None, 2, 2, 256)   1024        ['average_pooling2d_71[0][0]']
#  ormalization)
#
#  flatten_13 (Flatten)           (None, 512)          0           ['batch_normalization_66[0][0]']
#
#  flatten_14 (Flatten)           (None, 512)          0           ['batch_normalization_69[0][0]']
#
#  flatten_15 (Flatten)           (None, 1024)         0           ['batch_normalization_71[0][0]']
#
#  dropout_18 (Dropout)           (None, 512)          0           ['flatten_13[0][0]']
#
#  dropout_19 (Dropout)           (None, 512)          0           ['flatten_14[0][0]']
#
#  dropout_20 (Dropout)           (None, 1024)         0           ['flatten_15[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 2048)         0           ['dropout_18[0][0]',
#                                                                   'dropout_19[0][0]',
#                                                                   'dropout_20[0][0]']
#
#  dense_12 (Dense)               (None, 256)          524544      ['concatenate_3[0][0]']
#
#  dropout_21 (Dropout)           (None, 256)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 128)          32896       ['dropout_21[0][0]']
#
#  dropout_22 (Dropout)           (None, 128)          0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 3)            387         ['dropout_22[0][0]']
#
# ==================================================================================================
# Total params: 7,866,819
# Trainable params: 7,862,275
# Non-trainable params: 4,544
# __________________________________________________________________________________________________

# %%
test_scores = model.evaluate(X_test, y_test)

print("Testing Loss: %.2f%%"%(test_scores[0] * 100))
print("Testing Accuracy: %.2f%%"%(test_scores[1] * 100))
print("Testing Precision: %.2f%%"%(test_scores[2] * 100))
print("Testing Recall: %.2f%%"%(test_scores[3] * 100))
print("Testing AUC: %.2f%%"%(test_scores[4] * 100))
# Out:
# 2022-08-23 09:51:42.068640: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 20/20 [==============================] - 4s 32ms/step - loss: 0.0421 - acc: 0.9905 - prec: 0.9905 - rec: 0.9905 - auc: 0.9975
# Testing Loss: 4.21%
# Testing Accuracy: 99.05%
# Testing Precision: 99.05%
# Testing Recall: 99.05%
# Testing AUC: 99.75%

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(X_test)

cm=confusion_matrix(y_test.argmax(axis=1),y_pred.argmax(axis=1))
# Out:
# 20/20 [==============================] - 0s 15ms/step

# %%
cm
# Out:
# array([[ 89,   0,   0],
#        [  0, 315,   5],
#        [  0,   1, 223]])

# %%
import numpy as np
cm = np.array([[ 89,   0,   0],
       [  0, 315,   5],
       [  0,   1, 223]])

# %%
import matplotlib.pyplot as plt
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
plot_confusion_matrix(cm, CLASSES, normalize=False)
# Out:
# Confusion matrix, without normalization
# [[ 89   0   0]
#  [  0 315   5]
#  [  0   1 223]]

# %%
biclass = ['NON_DEMENTED', 'DEMENTED']

bicm = np.array([[315, 5],
         [1,89 + 223]])

# %%
plot_confusion_matrix(bicm, biclass, normalize=True)
# Out:
# Normalized confusion matrix
# [[0.984375   0.015625  ]
#  [0.00319489 0.99680511]]

# %%
biacc = (315 + 223 + 89) / (315+5+1+89+223)

# %%
biacc
# Out:
# 0.990521327014218

# %%
from fastai.vision.all import *

dls = ImageDataLoaders.from_folder(TEST_DIR, valid_pct=0.2, seed=30,
    item_tfms=Resize(480, method='squish'),
    batch_tfms=aug_transforms(size=128, min_scale=0.75))
dls.show_batch(max_n=9)
